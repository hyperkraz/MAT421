# %% [markdown]
# <a href="https://colab.research.google.com/github/hyperkraz/MAT421/blob/main/weeks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Weekly Plots**

# %%
import matplotlib.pyplot as plt
from google.colab import files

fig = plt.figure()
ax = fig.add_axes([1,0,75,20])
xax = ['Jan 7th', 'Jan 14th', 'Jan 21st', 'Jan 28th', 'Feb 7th', 'Feb 14th', 'Feb 21st', 'Feb 28th', 'Mar 7th', 'Mar 14th', 'Mar 21st', 'Mar 28th', 'Apr 7th', 'Apr 14th', 'Apr 21st', 'Apr 28th', 'May 7th', 'May 14th', 'May 21st', 'May 28th', 'Jun 7th', 'Jun 14th', 'Jun 21st', 'Jun 28th', 'Jul 7th', 'Jul 14th', 'Jul 21st', 'Jul 28th', 'Aug 7th', 'Aug 14th', 'Aug 21st', 'Aug 28th', 'Sep 7th', 'Sep 14th', 'Sep 21st', 'Sep 28th', 'Oct 7th', 'Oct 14th', 'Oct 21st', 'Oct 28th', 'Nov 7th', 'Nov 14th', 'Nov 21st', 'Nov 28th', 'Dec 7th', 'Dec 14th', 'Dec 21st', 'Dec 28th']
data = [82113.5,
91613.5,
94229.5,
56728.33333,
42646.66667,
15794.33333,
8415.333333,
6057,
4613,
3148,
1801,
2152,
4078.5,
3132,
2986.5,
3332.5,
4834,
3654,
3192.5,
3295.5,
6723.5,
5990,
9839,
12372,
17960.5,
14267.5,
14116,
13615,
20540,
12850.5,
12740,
13379,
17151.5,
10726,
11397.5,
9978,
14476.5,
10419,
10657.5,
12357.5,
23153.5,
20363.5,
25528,
24373.5,
38416.5,
38376,
30757.5,
33281.5]
ax.bar(xax,data)
plt.rcParams.update({'font.size': 125})
plt.title("Average New COVID Cases by Week", fontsize=500)
plt.savefig(f"out_{1-1:02d}.png", bbox_inches="tight")
files.download(f"out_{1-1:02d}.png")
plt.show()

# %%
import matplotlib.pyplot as plt
from google.colab import files

fig = plt.figure()
ax = fig.add_axes([1,0,75,20])
xax = ['Jan 7th', 'Jan 14th', 'Jan 21st', 'Jan 28th', 'Feb 7th', 'Feb 14th', 'Feb 21st', 'Feb 28th', 'Mar 7th', 'Mar 14th', 'Mar 21st', 'Mar 28th', 'Apr 7th', 'Apr 14th', 'Apr 21st', 'Apr 28th', 'May 7th', 'May 14th', 'May 21st', 'May 28th', 'Jun 7th', 'Jun 14th', 'Jun 21st', 'Jun 28th', 'Jul 7th', 'Jul 14th', 'Jul 21st', 'Jul 28th', 'Aug 7th', 'Aug 14th', 'Aug 21st', 'Aug 28th', 'Sep 7th', 'Sep 14th', 'Sep 21st', 'Sep 28th', 'Oct 7th', 'Oct 14th', 'Oct 21st', 'Oct 28th', 'Nov 7th', 'Nov 14th', 'Nov 21st', 'Nov 28th', 'Dec 7th', 'Dec 14th', 'Dec 21st', 'Dec 28th']
data = [883.5,
782,
685.5,
773.5,
914,
734.5,
484,
399.5,
174,
112.5,
96.5,
94,
84,
69,
86,
83.5,
131,
115,
111.5,
86,
141,
107,
115.5,
157,
215,
240,
314,
282,
426,
213.5,
203.5,
232,
256.5,
177,
220,
239,
235.5,
106.5,
201,
156.5,
306.5,
198.5,
223,
227,
429,
445,
556.5,
449.5]
ax.bar(xax,data)
plt.rcParams.update({'font.size': 125})
plt.title("Average New COVID Deaths by Week", fontsize=500)
plt.savefig(f"out_{1-1:02d}.png", bbox_inches="tight")
files.download(f"out_{1-1:02d}.png")
plt.show()
