# %% [markdown]
# <a href="https://colab.research.google.com/github/hyperkraz/MAT421/blob/main/HW3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **HW 3**

# %% [markdown]
# ***Problem 9***

# %%
import numpy as np
import matplotlib.pyplot as plt

def my_lagrange(x, y, X):
  Y0 = 0

  for j in range(len(x)):
    P1 = 1

    for k in range(len(x)):
      if k != j:
        Px = X - x[k]
        Dx = x[j] - x[k]
        
        P1 = P1 * Px/Dx
    Y0 = y[j] * P1 + Y0

  return Y0

# %%
x = [0, 1, 2, 3, 4]
y = [2, 1, 3, 5, 1]

X = np.linspace(0, 4, 101)

plt.figure(figsize = (10,8 ))
plt.plot(X, my_lagrange(x, y, X), 'b', label = 'interpolation')
plt.plot(x, y, 'ro', label = 'data points')

plt.xlabel('x')
plt.ylabel('y')

plt.title(f'Lagrange Interpolation of Data Points')
plt.legend()
plt.show()

# %% [markdown]
# ***Problem 10***

# %%
import numpy as np
import matplotlib.pyplot as plt

def div(x, y):
  m = len(y)
  co = np.zeros([m, m])
  co[:, 0] = y

  for k in range(1, m):
    for j in range(m - k):
      co[j][k] = (co[j + 1][k - 1] - co[j][k - 1]) / (x[j + k] - x[j])

  return co

def newton(co, x_data, x):
  z = len(x_data) - 1
  q = co[z]

  for h in range(1, z + 1):
    q = co[z - h] + (x - x_data[z - h]) * q

  return q

# %%
x = [0, 1, 2, 3, 4]
y = [2, 1, 3, 5, 1]

x_temp = np.arange(0, 5, 0.1)

a = div(x, y)[0, :]

y_temp = newton(a, x, x_temp)

plt.figure(figsize = (10, 8))
plt.plot(x, y, "rD", label = "data points")
plt.plot(x_temp, y_temp, "b", label = "interpolation")

plt.xlabel("X")
plt.ylabel("Y")

plt.title("Newton's")

plt.legend()
plt.show()
