# %% [markdown]
# <a href="https://colab.research.google.com/github/hyperkraz/MAT421/blob/main/timeplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Problem 5**

# %%
import calendar
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(365)
y = [241301.3333, 54967.33333, 12938, 13518, 15620.5, 36444, 63534.5, 56223, 49152.5, 51384, 90982, 154245.5]
x = calendar.month_abbr[1:]
plt.plot(x, y)
plt.xlabel('Month')
plt.title("Average New COVID Cases by Month")
# Out:
# Text(0.5, 1.0, 'Average New COVID Cases by Month')

# %%
import calendar
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(365)
y = [2072.333333,
1533.666667,
505.5,
326.5,
445,
523.5,
1180,
938,
910.5,
747.5,
907,
2080.5]
x = calendar.month_abbr[1:]
plt.plot(x, y)
plt.xlabel('Month')
plt.title("Average New COVID Deaths by Month")
# Out:
# Text(0.5, 1.0, 'Average New COVID Deaths by Month')

# %%
import calendar
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(365)
y = [241301.3333,
54967.33333,
12938,
13518,
15620.5,
36444,
63534.5,
56223,
49152.5,
51384,
90982,
154245.5]
x = calendar.month_abbr[1:]
plt.plot(x, y)
plt.xlabel('Month')
plt.title("Average New COVID Cases by Month - Counties")
# Out:
# Text(0.5, 1.0, 'Average New COVID Cases by Month - Counties')

# %%
import calendar
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(365)
y = [2072.333333,
1533.666667,
505.5,
326.5,
445,
523.5,
1180,
938,
910.5,
747.5,
907,
2080.5]
x = calendar.month_abbr[1:]
plt.plot(x, y)
plt.xlabel('Month')
plt.title("Average New COVID Deaths by Month - Counties")
# Out:
# Text(0.5, 1.0, 'Average New COVID Deaths by Month - Counties')
